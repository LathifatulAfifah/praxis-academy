# %%
# https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html

import numpy as np
import pandas as pd

# %%
# Object Creation

s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.874333  0.083617 -0.359298 -1.703080
# 2013-01-02  1.288043 -0.527961 -0.297795 -1.205443
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437
# 2013-01-04  0.592185  0.883985  0.581102  0.453708
# 2013-01-05 -0.846509 -0.741892  0.145074  0.790693
# 2013-01-06 -0.453745  0.858820 -0.600656  0.217466

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
# Viewing data

df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.874333  0.083617 -0.359298 -1.703080
# 2013-01-02  1.288043 -0.527961 -0.297795 -1.205443
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437
# 2013-01-04  0.592185  0.883985  0.581102  0.453708
# 2013-01-05 -0.846509 -0.741892  0.145074  0.790693

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.592185  0.883985  0.581102  0.453708
# 2013-01-05 -0.846509 -0.741892  0.145074  0.790693
# 2013-01-06 -0.453745  0.858820 -0.600656  0.217466

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of                    A         B         C         D
# 2013-01-01  0.874333  0.083617 -0.359298 -1.703080
# 2013-01-02  1.288043 -0.527961 -0.297795 -1.205443
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437
# 2013-01-04  0.592185  0.883985  0.581102  0.453708
# 2013-01-05 -0.846509 -0.741892  0.145074  0.790693
# 2013-01-06 -0.453745  0.858820 -0.600656  0.217466>

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.323571  0.355707  0.065131 -0.326349
# std    0.813112  0.903883  0.593731  0.985338
# min   -0.846509 -0.741892 -0.600656 -1.703080
# 25%   -0.218529 -0.375067 -0.343922 -1.031941
# 50%    0.539652  0.471218 -0.076360 -0.146986
# 75%    0.803796  0.877694  0.472095  0.394648
# max    1.288043  1.577672  0.922358  0.790693

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.874333    1.288043    0.487119    0.592185   -0.846509   -0.453745
# B    0.083617   -0.527961    1.577672    0.883985   -0.741892    0.858820
# C   -0.359298   -0.297795    0.922358    0.581102    0.145074   -0.600656
# D   -1.703080   -1.205443   -0.511437    0.453708    0.790693    0.217466

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.703080 -0.359298  0.083617  0.874333
# 2013-01-02 -1.205443 -0.297795 -0.527961  1.288043
# 2013-01-03 -0.511437  0.922358  1.577672  0.487119
# 2013-01-04  0.453708  0.581102  0.883985  0.592185
# 2013-01-05  0.790693  0.145074 -0.741892 -0.846509
# 2013-01-06  0.217466 -0.600656  0.858820 -0.453745

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-05 -0.846509 -0.741892  0.145074  0.790693
# 2013-01-02  1.288043 -0.527961 -0.297795 -1.205443
# 2013-01-01  0.874333  0.083617 -0.359298 -1.703080
# 2013-01-06 -0.453745  0.858820 -0.600656  0.217466
# 2013-01-04  0.592185  0.883985  0.581102  0.453708
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437

# %%
# Selection

df['A']
# Out:
# 2013-01-01    0.874333
# 2013-01-02    1.288043
# 2013-01-03    0.487119
# 2013-01-04    0.592185
# 2013-01-05   -0.846509
# 2013-01-06   -0.453745
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.874333  0.083617 -0.359298 -1.703080
# 2013-01-02  1.288043 -0.527961 -0.297795 -1.205443
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02  1.288043 -0.527961 -0.297795 -1.205443
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437
# 2013-01-04  0.592185  0.883985  0.581102  0.453708

# %%
# Selection by label

df.loc[dates[0]]
# Out:
# A    0.874333
# B    0.083617
# C   -0.359298
# D   -1.703080
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01  0.874333  0.083617
# 2013-01-02  1.288043 -0.527961
# 2013-01-03  0.487119  1.577672
# 2013-01-04  0.592185  0.883985
# 2013-01-05 -0.846509 -0.741892
# 2013-01-06 -0.453745  0.858820

# %%
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02  1.288043 -0.527961
# 2013-01-03  0.487119  1.577672
# 2013-01-04  0.592185  0.883985

# %%
df.loc['20130102', ['A', 'B']]
# Out:
# A    1.288043
# B   -0.527961
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], 'A']
# Out:
# 0.8743334993772978

# %%
df.at[dates[0], 'A']
# Out:
# 0.8743334993772978

# %%
# Selection by position

df.iloc[3]
# Out:
# A    0.592185
# B    0.883985
# C    0.581102
# D    0.453708
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.592185  0.883985
# 2013-01-05 -0.846509 -0.741892

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  1.288043 -0.297795
# 2013-01-03  0.487119  0.922358
# 2013-01-05 -0.846509  0.145074

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  1.288043 -0.527961 -0.297795 -1.205443
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.083617 -0.359298
# 2013-01-02 -0.527961 -0.297795
# 2013-01-03  1.577672  0.922358
# 2013-01-04  0.883985  0.581102
# 2013-01-05 -0.741892  0.145074
# 2013-01-06  0.858820 -0.600656

# %%
df.iloc[1, 1]
# Out:
# -0.5279610686663955

# %%
df.iat[1, 1]
# Out:
# -0.5279610686663955

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.874333  0.083617 -0.359298 -1.703080
# 2013-01-02  1.288043 -0.527961 -0.297795 -1.205443
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437
# 2013-01-04  0.592185  0.883985  0.581102  0.453708

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.874333  0.083617       NaN       NaN
# 2013-01-02  1.288043       NaN       NaN       NaN
# 2013-01-03  0.487119  1.577672  0.922358       NaN
# 2013-01-04  0.592185  0.883985  0.581102  0.453708
# 2013-01-05       NaN       NaN  0.145074  0.790693
# 2013-01-06       NaN  0.858820       NaN  0.217466

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.874333  0.083617 -0.359298 -1.703080    one
# 2013-01-02  1.288043 -0.527961 -0.297795 -1.205443    one
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437    two
# 2013-01-04  0.592185  0.883985  0.581102  0.453708  three
# 2013-01-05 -0.846509 -0.741892  0.145074  0.790693   four
# 2013-01-06 -0.453745  0.858820 -0.600656  0.217466  three

# %%
df2[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.487119  1.577672  0.922358 -0.511437   two
# 2013-01-05 -0.846509 -0.741892  0.145074  0.790693  four

# %%
# Setting

s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
# Setting values by label
df.at[dates[0], 'A'] = 0

# %%
# Setting values by position
df.iat[0, 1] = 0

# %%
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -0.359298  5
# 2013-01-02  1.288043 -0.527961 -0.297795  5
# 2013-01-03  0.487119  1.577672  0.922358  5
# 2013-01-04  0.592185  0.883985  0.581102  5
# 2013-01-05 -0.846509 -0.741892  0.145074  5
# 2013-01-06 -0.453745  0.858820 -0.600656  5

# %%
df2 = df.copy()
df2[df2>0] = -df2
df2
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -0.359298 -5
# 2013-01-02 -1.288043 -0.527961 -0.297795 -5
# 2013-01-03 -0.487119 -1.577672 -0.922358 -5
# 2013-01-04 -0.592185 -0.883985 -0.581102 -5
# 2013-01-05 -0.846509 -0.741892 -0.145074 -5
# 2013-01-06 -0.453745 -0.858820 -0.600656 -5

# %%
# Missing data

df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    A         B         C  D    E
# 2013-01-01  0.000000  0.000000 -0.359298  5  1.0
# 2013-01-02  1.288043 -0.527961 -0.297795  5  1.0
# 2013-01-03  0.487119  1.577672  0.922358  5  NaN
# 2013-01-04  0.592185  0.883985  0.581102  5  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    E
# 2013-01-01  0.000000  0.000000 -0.359298  5  1.0
# 2013-01-02  1.288043 -0.527961 -0.297795  5  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    E
# 2013-01-01  0.000000  0.000000 -0.359298  5  1.0
# 2013-01-02  1.288043 -0.527961 -0.297795  5  1.0
# 2013-01-03  0.487119  1.577672  0.922358  5  5.0
# 2013-01-04  0.592185  0.883985  0.581102  5  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
# Operations

# Stats
df.mean()
# Out:
# A    0.177849
# B    0.341771
# C    0.065131
# D    5.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.160176
# 2013-01-02    1.365572
# 2013-01-03    1.996787
# 2013-01-04    1.764318
# 2013-01-05    0.889168
# 2013-01-06    1.201105
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D
# 2013-01-01       NaN       NaN       NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN
# 2013-01-03 -0.512881  0.577672 -0.077642  4.0
# 2013-01-04 -2.407815 -2.116015 -2.418898  2.0
# 2013-01-05 -5.846509 -5.741892 -4.854926  0.0
# 2013-01-06       NaN       NaN       NaN  NaN

# %%
# Apply

df.apply(np.cumsum)
# Out:
#                    A         B         C   D
# 2013-01-01  0.000000  0.000000 -0.359298   5
# 2013-01-02  1.288043 -0.527961 -0.657093  10
# 2013-01-03  1.775162  1.049711  0.265266  15
# 2013-01-04  2.367347  1.933695  0.846368  20
# 2013-01-05  1.520838  1.191803  0.991442  25
# 2013-01-06  1.067093  2.050623  0.390786  30

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.134552
# B    2.319564
# C    1.523014
# D    0.000000
# dtype: float64

# %%
# Histogramming

s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    1
# 1    6
# 2    0
# 3    5
# 4    4
# 5    1
# 6    3
# 7    4
# 8    2
# 9    6
# dtype: int32

# %%
s.value_counts()
# Out:
# 6    2
# 4    2
# 1    2
# 5    1
# 3    1
# 2    1
# 0    1
# dtype: int64

# %%
# String Methods

s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
# Merge

# Concat
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.086692 -0.225546 -0.409880 -1.264899
# 1 -0.850969  1.585589 -0.657438 -0.122881
# 2  0.544263  0.122411 -1.147824  0.966327
# 3  0.127088 -1.531633  1.138773  1.684073
# 4 -0.825072 -0.275026  0.070004  0.139950
# 5  0.961283 -0.001987  0.246840  1.109467
# 6 -0.304717  1.349866 -0.132079 -1.083500
# 7  0.802721  0.586896 -1.911844 -0.066691
# 8 -0.885838 -0.019265  1.097097  0.658768
# 9 -0.077188  1.143580  0.452932 -1.639002

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.086692 -0.225546 -0.409880 -1.264899
# 1 -0.850969  1.585589 -0.657438 -0.122881
# 2  0.544263  0.122411 -1.147824  0.966327
# 3  0.127088 -1.531633  1.138773  1.684073
# 4 -0.825072 -0.275026  0.070004  0.139950
# 5  0.961283 -0.001987  0.246840  1.109467
# 6 -0.304717  1.349866 -0.132079 -1.083500
# 7  0.802721  0.586896 -1.911844 -0.066691
# 8 -0.885838 -0.019265  1.097097  0.658768
# 9 -0.077188  1.143580  0.452932 -1.639002

# %%
# Join

left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
# Append

df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0 -0.428237 -1.912630  1.261700 -0.929373
# 1  0.303162 -1.550847 -0.375307 -0.668654
# 2  0.606855  0.177262 -0.393019 -0.869189
# 3  0.284712  0.389100 -0.038333  0.453719
# 4 -0.082907 -0.917057 -0.464806  1.487560
# 5 -1.476887 -0.420984  0.765225 -0.541621
# 6  0.861986 -0.589026  1.012099 -1.576872
# 7 -0.644672 -1.319638 -0.442245  0.270012

# %%
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.428237 -1.912630  1.261700 -0.929373
# 1  0.303162 -1.550847 -0.375307 -0.668654
# 2  0.606855  0.177262 -0.393019 -0.869189
# 3  0.284712  0.389100 -0.038333  0.453719
# 4 -0.082907 -0.917057 -0.464806  1.487560
# 5 -1.476887 -0.420984  0.765225 -0.541621
# 6  0.861986 -0.589026  1.012099 -1.576872
# 7 -0.644672 -1.319638 -0.442245  0.270012
# 8  0.284712  0.389100 -0.038333  0.453719

# %%
# Grouping

df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                        'foo', 'bar', 'foo', 'foo'],
                    'B': ['one', 'one', 'two', 'three',
                        'two', 'two', 'one', 'three'],
                    'C': np.random.randn(8),
                    'D': np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.110224 -0.261026
# 1  bar    one -0.376352  0.643764
# 2  foo    two  1.225778  1.518970
# 3  bar  three -0.182278  0.131890
# 4  foo    two  0.326418 -1.055567
# 5  bar    two -0.453776 -0.541935
# 6  foo    one  1.772583 -1.394971
# 7  foo  three -1.277720 -0.108602

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -1.012406  0.233719
# foo  1.936834 -1.301195

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.376352  0.643764
#     three -0.182278  0.131890
#     two   -0.453776 -0.541935
# foo one    1.662359 -1.655996
#     three -1.277720 -0.108602
#     two    1.552195  0.463403

# %%
# Reshaping

# Stack
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                    'foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two',
                    'one', 'two', 'one', 'two']]))

index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one    -0.566802 -0.001910
#       two     0.534306  0.305884
# baz   one     0.155205  1.069629
#       two    -0.271119  0.177537

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.566802
#                B   -0.001910
#        two     A    0.534306
#                B    0.305884
# baz    one     A    0.155205
#                B    1.069629
#        two     A   -0.271119
#                B    0.177537
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.566802 -0.001910
#       two     0.534306  0.305884
# baz   one     0.155205  1.069629
#       two    -0.271119  0.177537

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.566802  0.534306
#       B -0.001910  0.305884
# baz   A  0.155205 -0.271119
#       B  1.069629  0.177537

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.566802  0.155205
#        B -0.001910  1.069629
# two    A  0.534306 -0.271119
#        B  0.305884  0.177537

# %%
# Pivot Tables

df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                    'B': ['A', 'B', 'C'] * 4,
                    'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                    'D': np.random.randn(12),
                    'E': np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.899829  1.201280
# 1     one  B  foo -0.259427 -0.466192
# 2     two  C  foo -0.405264  3.059615
# 3   three  A  bar  0.686876  0.737254
# 4     one  B  bar  0.164586 -0.382086
# 5     one  C  bar -0.360622 -1.092076
# 6     two  A  foo  0.109274  0.206080
# 7   three  B  foo -0.920556  1.210256
# 8     one  C  foo -0.210421 -0.048293
# 9     one  A  bar  1.132371 -1.351459
# 10    two  B  bar -0.095063 -1.358028
# 11  three  C  bar -0.986665 -1.207237

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  1.132371 -0.899829
#       B  0.164586 -0.259427
#       C -0.360622 -0.210421
# three A  0.686876       NaN
#       B       NaN -0.920556
#       C -0.986665       NaN
# two   A       NaN  0.109274
#       B -0.095063       NaN
#       C       NaN -0.405264

# %%
# Time Series

rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min').sum()
# Out:
# 2012-01-01    25976
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06   -0.244137
# 2012-03-07    0.303526
# 2012-03-08    0.418926
# 2012-03-09    2.472451
# 2012-03-10    0.490510
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.244137
# 2012-03-07 00:00:00+00:00    0.303526
# 2012-03-08 00:00:00+00:00    0.418926
# 2012-03-09 00:00:00+00:00    2.472451
# 2012-03-10 00:00:00+00:00    0.490510
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -0.244137
# 2012-03-06 19:00:00-05:00    0.303526
# 2012-03-07 19:00:00-05:00    0.418926
# 2012-03-08 19:00:00-05:00    2.472451
# 2012-03-09 19:00:00-05:00    0.490510
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31   -0.491586
# 2012-02-29   -0.655022
# 2012-03-31   -0.337887
# 2012-04-30    0.299411
# 2012-05-31   -0.561603
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01   -0.491586
# 2012-02   -0.655022
# 2012-03   -0.337887
# 2012-04    0.299411
# 2012-05   -0.561603
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -0.491586
# 2012-02-01   -0.655022
# 2012-03-01   -0.337887
# 2012-04-01    0.299411
# 2012-05-01   -0.561603
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990-03-01 09:00    1.636625
# 1990-06-01 09:00    1.703140
# 1990-09-01 09:00    0.888033
# 1990-12-01 09:00    0.111187
# 1991-03-01 09:00    0.726569
# Freq: H, dtype: float64

# %%
# Categorical

df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
                "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium",
                                                "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
# Plotting

ts = pd.Series(np.random.randn(1000),
index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                    columns=['A', 'B', 'C', 'D'])

df = df.cumsum()
plt.figure()

# %%
df.plot()

# %%
plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59
# 19  2000-01-20  -1.129026  -9.885407  -2.319287   4.910787
# 20  2000-01-21  -1.908731  -8.161179  -2.319893   5.701710
# 21  2000-01-22  -2.262221  -9.604970  -1.338686   6.673759
# 22  2000-01-23  -1.843385  -9.618519  -1.826845   5.987568
# 23  2000-01-24  -2.827965  -9.806540  -1.974014   6.949116
# 24  2000-01-25  -1.420807 -10.494262  -1.764443   6.709290
# 25  2000-01-26  -2.249743 -10.234084  -2.148411   5.849824
# 26  2000-01-27  -1.872300 -10.851130  -2.204308   6.462808
# 27  2000-01-28  -2.663692 -10.513684  -1.119942   4.440776
# 28  2000-01-29  -1.516636  -9.967894  -0.325297   5.116243
# 29  2000-01-30  -0.283110 -11.498497  -0.406469   3.433900
# ..         ...        ...        ...        ...        ...
# 970 2002-08-28 -45.448820 -27.954137  57.452178   9.767474
# 971 2002-08-29 -45.103819 -27.140641  57.709189   8.575238
# 972 2002-08-30 -43.917256 -26.786561  59.397316   9.221211
# 973 2002-08-31 -43.864629 -26.557656  58.395493  10.149082
# 974 2002-09-01 -44.818996 -25.991977  57.915550   9.837441
# 975 2002-09-02 -45.802849 -25.645677  57.728971   8.845601
# 976 2002-09-03 -45.953828 -24.909976  60.689241   6.707607
# 977 2002-09-04 -45.293927 -24.371617  60.932025   6.309691
# 978 2002-09-05 -44.335597 -25.112132  61.350629   6.641254
# 979 2002-09-06 -46.191631 -26.090550  62.243454   7.043221
# 980 2002-09-07 -47.381207 -25.104769  62.564498   5.440843
# 981 2002-09-08 -47.295136 -25.813587  62.827002   4.429775
# 982 2002-09-09 -46.159935 -25.895471  62.077501   3.912758
# 983 2002-09-10 -47.937911 -26.932164  61.918362   3.469788
# 984 2002-09-11 -48.577938 -26.877690  59.738515   4.157564
# 985 2002-09-12 -47.747667 -26.153438  60.451179   3.853939
# 986 2002-09-13 -46.636682 -26.558484  61.317859   3.867569
# 987 2002-09-14 -45.775105 -24.112134  60.382058   4.230220
# 988 2002-09-15 -46.285017 -25.112688  60.835720   3.991315
# 989 2002-09-16 -44.798020 -26.473864  62.196276   5.339889
# 990 2002-09-17 -45.331857 -26.220792  61.763119   5.061590
# 991 2002-09-18 -44.659101 -25.236602  61.721791   5.771891
# 992 2002-09-19 -46.883255 -23.754819  62.321724   6.506739
# 993 2002-09-20 -46.788325 -24.747619  61.863051   6.379226
# 994 2002-09-21 -45.806993 -22.231145  62.154278   5.355284
# 995 2002-09-22 -44.362416 -22.455845  62.281320   4.402248
# 996 2002-09-23 -44.371099 -22.811274  61.570901   2.564511
# 997 2002-09-24 -43.451548 -23.835596  62.573739   1.853921
# 998 2002-09-25 -44.011508 -22.832686  62.189048   2.530115
# 999 2002-09-26 -44.595334 -23.840122  64.288705   2.653880
#
# [1000 rows x 5 columns]

# %%
# Gotchas 

if pd.Series([False, True, False]):
    print("I was true")
Traceback
ValueError: The truth value of an array is ambiguous. Use a.empty, a.any() or a.all().
# Out:
#   File "<ipython-input-72-5bc19da4a332>", line 6
#     ValueError: The truth value of an array is ambiguous. Use a.empty, a.any() or a.all().
#                         ^
# SyntaxError: invalid syntax
